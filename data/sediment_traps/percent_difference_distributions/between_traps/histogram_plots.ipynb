# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_distribution(df, title=None, ax=None):
    same = df['same'].dropna()
    different = df['different'].dropna()

    bins = np.linspace(0, 1, 11)
    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 4))

    sns.histplot(same, bins=bins, stat='probability', alpha=0.5, label='Same trap type', kde=True, ax=ax)
    sns.histplot(different, bins=bins, stat='probability', alpha=0.5, label='Different trap type', kde=True, ax=ax)
    ax.set_xlabel('Percent Difference')
    ax.set_ylabel('Proportion')
    if title:
        ax.set_title(title)
    ax.legend()
    return ax

# %% [markdown]
# ## Total Sediment

# %% [markdown]
# Summer

# %%
df_summer = pd.read_csv('total_summer.csv')
plot_distribution(df_summer, title='Total Sediment - Summer')
plt.tight_layout()
plt.show()

# %% [markdown]
# Spring

# %%
df_spring = pd.read_csv('total_spring.csv')
plot_distribution(df_spring, title='Total Sediment - Spring')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Coarse Sand

# %% [markdown]
# Summer

# %%
df_summer = pd.read_csv('coarsesand_summer.csv')
plot_distribution(df_summer, title='Coarse Sand - Summer')
plt.tight_layout()
plt.show()

# %% [markdown]
# Spring

# %%
df_spring = pd.read_csv('coarsesand_spring.csv')
plot_distribution(df_spring, title='Coarse Sand - Spring')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Fine Sand

# %% [markdown]
# Summer

# %%
df_summer = pd.read_csv('finesand_summer.csv')
plot_distribution(df_summer, title='Fine Sand - Summer')
plt.tight_layout()
plt.show()

# %% [markdown]
# Spring

# %%
df_spring = pd.read_csv('finesand_spring.csv')
plot_distribution(df_spring, title='Fine Sand - Spring')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Silt

# %% [markdown]
# Summer

# %%
df_summer = pd.read_csv('silt_summer.csv')
plot_distribution(df_summer, title='Silt - Summer')
plt.tight_layout()
plt.show()

# %% [markdown]
# Spring

# %%
df_spring = pd.read_csv('silt_spring.csv')
plot_distribution(df_spring, title='Silt - Spring')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Clay

# %% [markdown]
# Summer

# %%
df_summer = pd.read_csv('clay_summer.csv')
plot_distribution(df_summer, title='Clay - Summer')
plt.tight_layout()
plt.show()

# %% [markdown]
# Spring

# %%
df_spring = pd.read_csv('clay_spring.csv')
plot_distribution(df_spring, title='Clay - Spring')
plt.tight_layout()
plt.show()
